# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('narr_data.csv', index_col = 0)
# Out:
# C:\Users\jvhua\Miniconda3\envs\tensflow\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (3,7,8,9,10,11,14,15,16,17,18,19,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#                     CloudCover  GaugeHeight GroupCode  HUC12  Latitude  \
# new_date
# 2019-03-24 12:28:00        NaN          NaN       NWA    NaN   38.6336
# 2019-03-24 12:46:00        NaN          NaN       NWA    NaN   38.6422
# 2019-03-24 13:05:00        NaN          NaN       NWA    NaN   38.6013
# 2019-03-24 15:20:00        NaN          NaN       NWA    NaN   38.5645
# 2019-03-24 15:34:00        NaN          NaN       NWA    NaN   38.5583
#
#                      Longitude Method Other Conditions Rainfall  \
# new_date
# 2019-03-24 12:28:00   -75.6177    NaN              NaN      NaN
# 2019-03-24 12:46:00   -75.6068    NaN              NaN      NaN
# 2019-03-24 13:05:00   -75.6563    NaN              NaN      NaN
# 2019-03-24 15:20:00   -75.6723    NaN              NaN      NaN
# 2019-03-24 15:34:00   -75.5696    NaN              NaN      NaN
#
#                     Rainfall Within 24 Hours Rainfall Within 48 Hours  \
# new_date
# ...

# %%
df.shape
# Out:
# (103295, 69)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103295 entries, 2019-03-24 12:28:00 to 2016-11-08 09:00:00
# Data columns (total 69 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   CloudCover                               67874 non-null   object
#  1   GaugeHeight                              10665 non-null   float64
#  2   GroupCode                                18242 non-null   object
#  3   HUC12                                    85053 non-null   float64
#  4   Latitude                                 103295 non-null  float64
#  5   Longitude                                103295 non-null  float64
#  6   Method                                   85053 non-null   object
#  7   Other Conditions                         496 non-null     object
#  8   Rainfall                                 2275 non-null    object
# ...

# %%
df['TN'] = df['TN'].replace(np.nan, 'nan')

# %%
df_nitro = df[df['TN'] != 'nan']

# %%
df_nitro
# Out:
#                                 CloudCover  GaugeHeight GroupCode  \
# new_date
# 2019-03-24 12:28:00                    NaN          NaN       NWA
# 2019-03-24 12:46:00                    NaN          NaN       NWA
# 2019-03-24 13:05:00                    NaN          NaN       NWA
# 2019-03-24 15:20:00                    NaN          NaN       NWA
# 2019-03-24 15:34:00                    NaN          NaN       NWA
# ...                                    ...          ...       ...
# 2015-08-13 08:30:00          Clear (0-10%)          NaN       NaN
# 2017-03-07 09:30:00          Clear (0-10%)          NaN       NaN
# 2020-01-28 08:45:00  Cloud (No Percentage)          NaN       NaN
# 2020-02-20 08:30:00  Cloud (No Percentage)          NaN       NaN
# 2016-11-08 09:00:00                    NaN          NaN       NaN
#
#                             HUC12  Latitude  Longitude Method  \
# new_date
# 2019-03-24 12:28:00           NaN  38.63360  -75.61770    NaN
# ...

# %%
df_nitro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67040 entries, 2019-03-24 12:28:00 to 2016-11-08 09:00:00
# Data columns (total 69 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   CloudCover                               48297 non-null  object
#  1   GaugeHeight                              9683 non-null   float64
#  2   GroupCode                                2487 non-null   object
#  3   HUC12                                    64553 non-null  float64
#  4   Latitude                                 67040 non-null  float64
#  5   Longitude                                67040 non-null  float64
#  6   Method                                   64553 non-null  object
#  7   Other Conditions                         33 non-null     object
#  8   Rainfall                                 53 non-null     object
#  9   Rainfall Within 24 Hours                 38 non-null     object
# ...

# %%
df_nitro[['Station', 'StationCode', 'StationName']].tail(10)
# Out:
#                     Station StationCode StationName
# new_date
# 2017-06-13 09:00:00   LE5.6         NaN         NaN
# 2019-08-13 08:15:00   LE5.6         NaN         NaN
# 2017-02-07 09:00:00   LE5.6         NaN         NaN
# 2016-02-09 08:45:00   LE5.6         NaN         NaN
# 2019-04-16 08:50:00   LE5.6         NaN         NaN
# 2015-08-13 08:30:00   LE5.4         NaN         NaN
# 2017-03-07 09:30:00   LE5.6         NaN         NaN
# 2020-01-28 08:45:00   LE5.6         NaN         NaN
# 2020-02-20 08:30:00   LE5.6         NaN         NaN
# 2016-11-08 09:00:00   LE5.6         NaN         NaN

# %%
df_nitro[['Station', 'StationCode', 'StationName']].head(10)
# Out:
#                     Station StationCode StationName
# new_date
# 2019-03-24 12:28:00     NaN   NWA.DENA2       DENA2
# 2019-03-24 12:46:00     NaN   NWA.COBR1       COBR1
# 2019-03-24 13:05:00     NaN   NWA.DENA4       DENA4
# 2019-03-24 15:20:00     NaN   NWA.BRCR1       BRCR1
# 2019-03-24 15:34:00     NaN   NWA.BRCR3       BRCR3
# 2019-03-24 16:00:00     NaN   NWA.BRCR2       BRCR2
# 2017-03-25 14:50:00     NaN   NWA.BRCR2       BRCR2
# 2018-03-25 13:50:00     NaN   NWA.BRCR1       BRCR1
# 2018-03-25 15:55:00     NaN   NWA.DENA4       DENA4
# 2018-03-25 16:22:00     NaN   NWA.BRCR3       BRCR3

# %%
df_nitro.columns
# Out:
# Index(['CloudCover', 'GaugeHeight', 'GroupCode', 'HUC12', 'Latitude',
#        'Longitude', 'Method', 'Other Conditions', 'Rainfall',
#        'Rainfall Within 24 Hours', 'Rainfall Within 48 Hours', 'SampleDepth',
#        'SampleId', 'Station', 'StationCode', 'StationName',
#        'Weather Conditions Day Before Yesterday', 'Weather Conditions Today',
#        'Weather Conditions Yesterday', 'WindDirection', 'WindSpeed', 'state',
#        'HUC12_', 'HUCNAME_', 'FIPS_', 'COUNTY_', 'STATE_', 'areaacres',
#        'states', 'huc12', 'za_mean', 'lc_0', 'lc_11', 'lc_21', 'lc_22',
#        'lc_23', 'lc_24', 'lc_31', 'lc_41', 'lc_42', 'lc_43', 'lc_52', 'lc_71',
#        'lc_81', 'lc_82', 'lc_90', 'lc_95', 'month', 'year', 'week',
#        'dayofweek', 'hour', 'min', 'quarter', 'DO', 'TN', 'TP', 'airtemp_narr',
#        'precip3_narr', 'humidity_narr', 'cl_cover_narr', 'sfc_runoff',
#        'sfc_air_narr', 'u_wind_narr', 'v_wind_narr', 'windspeed_narr',
# ...

# %%
df_nitro1 = df_nitro.loc[:,['CloudCover', 'HUC12', 'Latitude',
       'Longitude', 'Method', 'SampleDepth',
       'SampleId', 'Station', 'StationCode', 'WindDirection', 'WindSpeed',
       'HUC12_', 'HUCNAME_', 'FIPS_', 'COUNTY_', 'STATE_', 'areaacres',
       'states', 'huc12', 'za_mean', 'lc_0', 'lc_11', 'lc_21', 'lc_22',
       'lc_23', 'lc_24', 'lc_31', 'lc_41', 'lc_42', 'lc_43', 'lc_52', 'lc_71',
       'lc_81', 'lc_82', 'lc_90', 'lc_95', 'month', 'year', 'week',
       'dayofweek', 'hour', 'min', 'quarter', 'DO', 'TN', 'TP', 'airtemp_narr',
       'precip3_narr', 'humidity_narr', 'cl_cover_narr', 'sfc_runoff',
       'sfc_air_narr', 'u_wind_narr', 'v_wind_narr', 'windspeed_narr',
       'wdirection_narr', 'precip24_narr', 'precip48_narr']]

# %%
df_nitro1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67040 entries, 2019-03-24 12:28:00 to 2016-11-08 09:00:00
# Data columns (total 58 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CloudCover       48297 non-null  object
#  1   HUC12            64553 non-null  float64
#  2   Latitude         67040 non-null  float64
#  3   Longitude        67040 non-null  float64
#  4   Method           64553 non-null  object
#  5   SampleDepth      67040 non-null  float64
#  6   SampleId         67040 non-null  float64
#  7   Station          64553 non-null  object
#  8   StationCode      2487 non-null   object
#  9   WindDirection    25615 non-null  object
#  10  WindSpeed        20186 non-null  object
#  11  HUC12_           67040 non-null  int64
#  12  HUCNAME_         67040 non-null  object
#  13  FIPS_            67040 non-null  int64
#  14  COUNTY_          67040 non-null  object
#  15  STATE_           67040 non-null  object
# ...

# %%
df_nitro1['Station'] = df_nitro1['Station'].replace(np.nan, 'nan')

# %%
df_nitro1['StationC'] = np.where(df_nitro1['Station'] != 'nan', df_nitro1['Station'], df_nitro1['StationCode'])

# %%
df_nitro1 = df_nitro1.drop(columns = ['Station', 'StationCode'])

# %%
df_nitro1
# Out:
#                                 CloudCover         HUC12  Latitude  Longitude  \
# new_date
# 2019-03-24 12:28:00                    NaN           NaN  38.63360  -75.61770
# 2019-03-24 12:46:00                    NaN           NaN  38.64220  -75.60680
# 2019-03-24 13:05:00                    NaN           NaN  38.60130  -75.65630
# 2019-03-24 15:20:00                    NaN           NaN  38.56450  -75.67230
# 2019-03-24 15:34:00                    NaN           NaN  38.55830  -75.56960
# ...                                    ...           ...       ...        ...
# 2015-08-13 08:30:00          Clear (0-10%)  2.080208e+10  36.95486  -76.39275
# 2017-03-07 09:30:00          Clear (0-10%)  2.080208e+10  36.90456  -76.33836
# 2020-01-28 08:45:00  Cloud (No Percentage)  2.080208e+10  36.90456  -76.33836
# 2020-02-20 08:30:00  Cloud (No Percentage)  2.080208e+10  36.90456  -76.33836
# 2016-11-08 09:00:00                    NaN  2.080208e+10  36.90456  -76.33836
#
# ...

# %%
df_nitro1[df_nitro1['SampleId'] == 1.0]
# Out:
#                                     CloudCover  HUC12   Latitude  Longitude  \
# new_date
# 2019-03-24 12:28:00                        NaN    NaN  38.633600 -75.617700
# 2019-03-24 12:46:00                        NaN    NaN  38.642200 -75.606800
# 2019-03-24 13:05:00                        NaN    NaN  38.601300 -75.656300
# 2019-03-24 15:20:00                        NaN    NaN  38.564500 -75.672300
# 2019-03-24 15:34:00                        NaN    NaN  38.558300 -75.569600
# ...                                        ...    ...        ...        ...
# 2018-12-19 12:20:00  Partially cloudy (10-50%)    NaN  37.596970 -77.469020
# 2018-12-19 13:10:00  Partially cloudy (10-50%)    NaN  37.598320 -77.468030
# 2017-12-21 12:30:00                        NaN    NaN  37.597255 -77.473902
# 2017-12-21 13:15:00                        NaN    NaN  37.596970 -77.469020
# 2017-12-21 13:50:00                        NaN    NaN  37.598320 -77.468030
#
# ...

# %%
df_nitro1 = df_nitro1.reset_index()

# %%
df2 = pd.read_csv('data_ph_sa.csv', index_col = 0)

# %%
df2.columns
# Out:
# Index(['new_date', 'HUC12_', 'Latitude', 'Longitude', 'PH', 'SA'], dtype='object')

# %%
df_nitro2 = pd.merge(df_nitro1, df2,  how='left', on = ['new_date', 'HUC12_', 'Latitude', 'Longitude'])

# %%
df_nitro2 = df_nitro2.set_index('new_date')

# %%
df_nitro2
# Out:
#                                 CloudCover         HUC12  Latitude  Longitude  \
# new_date
# 2019-03-24 12:28:00                    NaN           NaN  38.63360  -75.61770
# 2019-03-24 12:46:00                    NaN           NaN  38.64220  -75.60680
# 2019-03-24 13:05:00                    NaN           NaN  38.60130  -75.65630
# 2019-03-24 15:20:00                    NaN           NaN  38.56450  -75.67230
# 2019-03-24 15:34:00                    NaN           NaN  38.55830  -75.56960
# ...                                    ...           ...       ...        ...
# 2015-08-13 08:30:00          Clear (0-10%)  2.080208e+10  36.95486  -76.39275
# 2017-03-07 09:30:00          Clear (0-10%)  2.080208e+10  36.90456  -76.33836
# 2020-01-28 08:45:00  Cloud (No Percentage)  2.080208e+10  36.90456  -76.33836
# 2020-02-20 08:30:00  Cloud (No Percentage)  2.080208e+10  36.90456  -76.33836
# 2016-11-08 09:00:00                    NaN  2.080208e+10  36.90456  -76.33836
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import folium
from tqdm import tqdm

# %%
lat = list(df_nitro2['Latitude'].unique())
lon = list(df_nitro2['Longitude'].unique())
info_list = list(df_nitro2['StationC'].unique())

# %%
map_ = folium.Map(location = [38, -75], zoom_start = 8,tiles = "Stamen Terrain")
fg = folium.FeatureGroup(name = 'My Map')

for lt, ln, info in zip(lat,lon, info_list):
    fg.add_child(folium.Marker(location =[lt, ln], popup = info, icon = folium.Icon(color ='blue' )))
#,en_info_list
#, popup = info
map_.add_child(fg)

map_
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
imp_constant = SimpleImputer(strategy='constant', fill_value='missing')
ohe = OneHotEncoder()
imp_ohe = make_pipeline(imp_constant, ohe)

# %%
ct = make_column_transformer(
    (imp_mean, ['HUC12', 'Latitude', 'Longitude', 'SampleDepth',
       'SampleId', 'HUC12_', 'FIPS_',
       'areaacres', 'za_mean',
       'lc_11', 'lc_21', 'lc_22', 'lc_23', 'lc_24', 'lc_31', 'lc_41', 'lc_42',
       'lc_43', 'lc_52', 'lc_71', 'lc_81', 'lc_82', 'lc_90', 'lc_95', 'month',
       'year', 'week', 'dayofweek', 'hour', 'min', 'quarter', 'DO', 'TP',
       'airtemp_narr', 'precip3_narr', 'humidity_narr', 'cl_cover_narr',
       'sfc_runoff', 'sfc_air_narr', 'u_wind_narr', 'v_wind_narr',
       'windspeed_narr', 'wdirection_narr', 'precip24_narr', 'precip48_narr', 'PH', 'SA']),
    (imp_ohe, ['CloudCover', 'Method', 'WindDirection', 'WindSpeed',  'COUNTY_', 'STATE_']),
    remainder='passthrough')

# %%
df_nitro2.columns
# Out:
# Index(['CloudCover', 'HUC12', 'Latitude', 'Longitude', 'Method', 'SampleDepth',
#        'SampleId', 'WindDirection', 'WindSpeed', 'HUC12_', 'HUCNAME_', 'FIPS_',
#        'COUNTY_', 'STATE_', 'areaacres', 'states', 'huc12', 'za_mean', 'lc_0',
#        'lc_11', 'lc_21', 'lc_22', 'lc_23', 'lc_24', 'lc_31', 'lc_41', 'lc_42',
#        'lc_43', 'lc_52', 'lc_71', 'lc_81', 'lc_82', 'lc_90', 'lc_95', 'month',
#        'year', 'week', 'dayofweek', 'hour', 'min', 'quarter', 'DO', 'TN', 'TP',
#        'airtemp_narr', 'precip3_narr', 'humidity_narr', 'cl_cover_narr',
#        'sfc_runoff', 'sfc_air_narr', 'u_wind_narr', 'v_wind_narr',
#        'windspeed_narr', 'wdirection_narr', 'precip24_narr', 'precip48_narr',
#        'StationC', 'PH', 'SA'],
#       dtype='object')

# %%
df_nitro2.loc[:, df_nitro2.dtypes == object]
# Out:
#                                 CloudCover Method WindDirection WindSpeed  \
# new_date
# 2019-03-24 12:28:00                    NaN    NaN           NaN       NaN
# 2019-03-24 12:46:00                    NaN    NaN           NaN       NaN
# 2019-03-24 13:05:00                    NaN    NaN           NaN       NaN
# 2019-03-24 15:20:00                    NaN    NaN           NaN       NaN
# 2019-03-24 15:34:00                    NaN    NaN           NaN       NaN
# ...                                    ...    ...           ...       ...
# 2015-08-13 08:30:00          Clear (0-10%)   F04            NaN       NaN
# 2017-03-07 09:30:00          Clear (0-10%)   F04            NaN       NaN
# 2020-01-28 08:45:00  Cloud (No Percentage)   F04            NaN       NaN
# 2020-02-20 08:30:00  Cloud (No Percentage)   F04            NaN       NaN
# 2016-11-08 09:00:00                    NaN   F04            NaN       NaN
#
# ...

# %%
df_nitro2['TN'] = df_nitro2['TN'].apply(lambda x: float(x))

# %%
df_nitro2[df_nitro2['lc_0'] > 0]
# Out:
# Empty DataFrame
# Columns: [CloudCover, HUC12, Latitude, Longitude, Method, SampleDepth, SampleId, WindDirection, WindSpeed, HUC12_, HUCNAME_, FIPS_, COUNTY_, STATE_, areaacres, states, huc12, za_mean, lc_0, lc_11, lc_21, lc_22, lc_23, lc_24, lc_31, lc_41, lc_42, lc_43, lc_52, lc_71, lc_81, lc_82, lc_90, lc_95, month, year, week, dayofweek, hour, min, quarter, DO, TN, TP, airtemp_narr, precip3_narr, humidity_narr, cl_cover_narr, sfc_runoff, sfc_air_narr, u_wind_narr, v_wind_narr, windspeed_narr, wdirection_narr, precip24_narr, precip48_narr, StationC, PH, SA]
# Index: []

# %%
df_nitro3 = df_nitro2.drop(columns = ['HUCNAME_', 'states', 'huc12', 'lc_0', 'StationC'])

# %%
corr = df_nitro3.corr()

# %%
m = ~(corr.mask(np.eye(len(corr), dtype=bool)).abs() > 0.85).any()

raw = corr.loc[m, m]

# %%
raw.columns
# Out:
# Index(['Latitude', 'Longitude', 'SampleDepth', 'SampleId', 'FIPS_',
#        'areaacres', 'za_mean', 'lc_11', 'lc_21', 'lc_31', 'lc_41', 'lc_42',
#        'lc_43', 'lc_52', 'lc_71', 'lc_81', 'lc_82', 'lc_90', 'lc_95', 'year',
#        'dayofweek', 'hour', 'min', 'DO', 'TN', 'TP', 'precip3_narr',
#        'humidity_narr', 'cl_cover_narr', 'sfc_runoff', 'windspeed_narr',
#        'precip24_narr', 'precip48_narr', 'PH', 'SA'],
#       dtype='object')

# %%
#“most_frequent”,
imp_freq = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

# %%
ct2 = make_column_transformer(
    (imp_freq, ['Latitude', 'Longitude', 'SampleDepth', 'SampleId', 'FIPS_',
       'areaacres', 'za_mean', 'lc_11', 'lc_21', 'lc_31', 'lc_41', 'lc_42',
       'lc_43', 'lc_52', 'lc_71', 'lc_81', 'lc_82', 'lc_90', 'lc_95', 'year',
       'dayofweek', 'hour', 'min', 'DO', 'TP', 'precip3_narr',
       'humidity_narr', 'cl_cover_narr', 'sfc_runoff', 'windspeed_narr',
       'precip24_narr', 'precip48_narr', 'PH', 'SA']),
    (imp_ohe, ['CloudCover', 'Method', 'WindDirection', 'WindSpeed',  'COUNTY_', 'STATE_']),
    remainder='passthrough')

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=3)

# %%
ct4 = make_column_transformer(
    (imputer, ['Latitude', 'Longitude', 'SampleDepth', 'SampleId', 'FIPS_',
       'areaacres', 'za_mean', 'lc_11', 'lc_21', 'lc_31', 'lc_41', 'lc_42',
       'lc_43', 'lc_52', 'lc_71', 'lc_81', 'lc_82', 'lc_90', 'lc_95', 'year',
       'dayofweek', 'hour', 'min', 'DO', 'TP', 'precip3_narr',
       'humidity_narr', 'cl_cover_narr', 'sfc_runoff', 'windspeed_narr',
       'precip24_narr', 'precip48_narr', 'PH', 'SA']),
    (imp_ohe, ['CloudCover', 'Method', 'WindDirection', 'WindSpeed',  'COUNTY_', 'STATE_']),
    remainder='passthrough')

# %%
ct3 = make_column_transformer(
    (imp_mean, ['Latitude', 'Longitude', 'SampleDepth', 'SampleId', 'FIPS_',
       'areaacres', 'za_mean', 'lc_11', 'lc_21', 'lc_31', 'lc_41', 'lc_42',
       'lc_43', 'lc_52', 'lc_71', 'lc_81', 'lc_82', 'lc_90', 'lc_95', 'year',
       'dayofweek', 'hour', 'min', 'DO', 'TP', 'precip3_narr',
       'humidity_narr', 'cl_cover_narr', 'sfc_runoff', 'windspeed_narr',
       'precip24_narr', 'precip48_narr', 'PH', 'SA']),
    remainder='passthrough')

# %%
#df_nitro3.to_csv('dfnitro3.csv')

# %%
df_nitro4 = df_nitro3[['Latitude', 'Longitude', 'SampleDepth', 'SampleId', 'FIPS_',
       'areaacres', 'za_mean', 'lc_11', 'lc_21', 'lc_31', 'lc_41', 'lc_42',
       'lc_43', 'lc_52', 'lc_71', 'lc_81', 'lc_82', 'lc_90', 'lc_95', 'year',
       'dayofweek', 'hour', 'min', 'DO', 'TN', 'TP', 'precip3_narr',
       'humidity_narr', 'cl_cover_narr', 'sfc_runoff', 'windspeed_narr',
       'precip24_narr', 'precip48_narr', 'PH', 'SA', 'CloudCover', 'Method', 'WindDirection', 'WindSpeed',  'COUNTY_', 'STATE_']]

# %%
df_nitro5 = df_nitro3[['Latitude', 'Longitude', 'SampleDepth', 'SampleId', 'FIPS_',
       'areaacres', 'za_mean', 'lc_11', 'lc_21', 'lc_31', 'lc_41', 'lc_42',
       'lc_43', 'lc_52', 'lc_71', 'lc_81', 'lc_82', 'lc_90', 'lc_95', 'year',
       'dayofweek', 'hour', 'min', 'DO', 'TN', 'TP', 'precip3_narr',
       'humidity_narr', 'cl_cover_narr', 'sfc_runoff', 'windspeed_narr',
       'precip24_narr', 'precip48_narr', 'PH', 'SA']]

# %%
df_nitro4.corr()['TN'].sort_values(ascending = False)
# Out:
# TN                1.000000
# TP                0.314826
# Latitude          0.185722
# za_mean           0.150862
# lc_82             0.150244
# lc_81             0.132494
# sfc_runoff        0.109034
# precip24_narr     0.072878
# DO                0.066739
# precip48_narr     0.066193
# year              0.064149
# dayofweek         0.063673
# lc_21             0.042665
# lc_43             0.042605
# Longitude         0.042429
# precip3_narr      0.038554
# cl_cover_narr     0.030745
# windspeed_narr    0.017266
# hour              0.014247
# lc_41             0.014008
# humidity_narr     0.005685
# SampleId          0.000839
# lc_90            -0.001892
# lc_31            -0.016172
# lc_95            -0.023247
# lc_52            -0.035535
# lc_42            -0.036421
# min              -0.039054
# lc_71            -0.055465
# PH               -0.063727
# FIPS_            -0.082710
# areaacres        -0.085289
# SampleDepth      -0.091558
# lc_11            -0.129182
# ...

# %%
X = df_nitro4.loc[:, df_nitro4.columns != 'TN']
y = df_nitro4.loc[:, 'TN']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.33, random_state=777)

# %%
X1 = df_nitro3.loc[:, df_nitro3.columns != 'TN']
y1 = df_nitro3.loc[:, 'TN']

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1,y1, test_size=0.33, random_state=777)

# %%
######group correlated features#####

# %%
# corrmat = X_train1.corr()
# corrmat = corrmat.abs().unstack()
# corrmat = corrmat.sort_values(ascending = False)
# corrmat = corrmat[corrmat >= 0.8]
# corrmat = corrmat[corrmat<1]
# corrmat = pd.DataFrame(corrmat).reset_index()
# corrmat.columns = ['feature1', 'feature2', 'corr']
# corrmat.head()
# Out:
#           feature1         feature2      corr
# 0  wdirection_narr      u_wind_narr  1.000000
# 1      u_wind_narr  wdirection_narr  1.000000
# 2             week            month  0.993750
# 3            month             week  0.993750
# 4           HUC12_            HUC12  0.978829

# %%
# grouped_feature_ls = []
# correlated_groups = []

# for feature in corrmat.feature1.unique():
#     if feature not in grouped_feature_ls:
#         correlated_block = corrmat[corrmat.feature1 == feature]
#         grouped_feature_ls = grouped_feature_ls + list(correlated_block.feature2.unique()) + [feature]
#         correlated_groups.append(correlated_block)
# print('found {} correlated groups'.format(len(correlated_groups)))
# print('out of {} total features'.format(X_train1.shape[1]))
# Out:
# found 7 correlated groups
# out of 53 total features

# %%
rf = RandomForestRegressor(verbose = True, n_jobs = -1)
pipe = make_pipeline(ct4, rf)

# %%
pipe.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  6.7min finished
# Pipeline(memory=None,
#          steps=[('columntransformer',
#                  ColumnTransformer(n_jobs=None, remainder='passthrough',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('knnimputer',
#                                                   KNNImputer(add_indicator=False,
#                                                              copy=True,
#                                                              metric='nan_euclidean',
#                                                              missing_values=nan,
#                                                              n_neighbors=3,
# ...

# %%
y_pred = pipe.predict(X_test)
# Out:
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 100 out of 100 | elapsed:    0.1s finished

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_pred, y_test)
# Out:
# 5.017395947175454

# %%
r2_score(y_pred, y_test)
# Out:
# 0.3586333571769583

# %%
for col, score in zip(X_train.columns, pipe['randomforestregressor'].feature_importances_):
    print(col,score)
# Out:
# Latitude 0.10967839337732288
# Longitude 0.013440359025166998
# SampleDepth 0.018118586052309288
# SampleId 0.02141639157392304
# FIPS_ 0.01892626484603265
# areaacres 0.001030458133229628
# za_mean 0.02716582419466846
# lc_11 0.026669843425394732
# lc_21 0.01807864693929179
# lc_31 0.005164849406395767
# lc_41 0.0025581634061363715
# lc_42 0.021536781117196847
# lc_43 0.02190290356442091
# lc_52 0.028413885992318505
# lc_71 0.02780859967392668
# lc_81 0.0020199059049549437
# lc_82 0.06438928103262712
# lc_90 0.032732539118555205
# lc_95 0.010626290721020852
# year 0.0023192872257519594
# dayofweek 0.019382200204566432
# hour 0.000799304049412281
# min 0.0009787558743340305
# DO 0.22127991500287014
# TP 0.011026055276929484
# precip3_narr 0.04415068121004308
# humidity_narr 0.030826606893067043
# cl_cover_narr 0.003263672391354382
# sfc_runoff 0.01156167828868498
# windspeed_narr 0.022397024197583746
# precip24_narr 0.030823957595475307
# precip48_narr 0.018778713146962125
# ...

# %%
# Importing module and initializing setup
from pycaret.regression import *

# %%
clf1 = setup(data = df_nitro3, target = 'TN', feature_selection = True, ignore_low_variance = True, remove_outliers = True)
# Out:
#
# Setup Succesfully Completed.
# <style  type="text/css" >
#     #T_58c80cfe_ea54_11ea_9b19_04ed3352dca7row4_col1 {
#             background-color:  yellow;
#         }    #T_58c80cfe_ea54_11ea_9b19_04ed3352dca7row22_col1 {
#             background-color:  yellow;
#         }    #T_58c80cfe_ea54_11ea_9b19_04ed3352dca7row26_col1 {
#             background-color:  yellow;
#         }    #T_58c80cfe_ea54_11ea_9b19_04ed3352dca7row37_col1 {
#             background-color:  yellow;
#         }</style><table id="T_58c80cfe_ea54_11ea_9b19_04ed3352dca7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_58c80cfe_ea54_11ea_9b19_04ed3352dca7level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
clf1
# Out:
# (                     COUNTY__Louisa County  COUNTY__Shenandoah County  \
#  new_date
#  2019-03-24 12:28:00                    0.0                        0.0
#  2019-03-24 12:46:00                    0.0                        0.0
#  2019-03-24 13:05:00                    0.0                        0.0
#  2019-03-24 15:20:00                    0.0                        0.0
#  2019-03-24 15:34:00                    0.0                        0.0
#  ...                                    ...                        ...
#  2015-08-13 08:30:00                    0.0                        0.0
#  2017-03-07 09:30:00                    0.0                        0.0
#  2020-01-28 08:45:00                    0.0                        0.0
#  2020-02-20 08:30:00                    0.0                        0.0
#  2016-11-08 09:00:00                    0.0                        0.0
#
#                       COUNTY__Newport News city  COUNTY__Loudoun County  \
#  new_date
# ...
