# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import seaborn as sns

# %%
#Load in old dataframe 
df = pd.read_csv('Water_FINAL.csv', index_col = 0, low_memory = False)
# Out:
# C:\Users\jvhua\Miniconda3\envs\tensflow\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
#Drop unnecessary columns 
df = df.drop(columns = 'Unnamed: 0.1')

# %%
df.columns
# Out:
# Index(['Agency', 'BiasPC', 'CloudCover', 'Comments', 'Cruise', 'Database',
#        'Date', 'FieldActivityEventType', 'FieldActivityRemark', 'FlowStage',
#        'GaugeHeight', 'GroupCode', 'HUC12', 'Lab', 'Latitude', 'Layer',
#        'Longitude', 'LowerPycnocline', 'MeasureValue', 'Method',
#        'ModifiedDate', 'Other Comments', 'Other Conditions', 'Parameter',
#        'ParameterName_CBP', 'ParameterName_CMC', 'PrecipType', 'PrecisionPC',
#        'Pressure', 'Problem', 'Program', 'Project', 'Qualifier', 'Rainfall',
#        'Rainfall Within 24 Hours', 'Rainfall Within 48 Hours', 'SampleDepth',
#        'SampleId', 'SampleReplicateType', 'SampleType', 'Sea State', 'Source',
#        'Station', 'StationCode', 'StationName', 'Stream Flow', 'Tidal Stage',
#        'TideStage', 'TierLevel', 'Time', 'TotalDepth', 'Unit',
#        'UpperPycnocline', 'Water Color', 'Water Color Description',
#        'Water Odor', 'Water Odor Description', 'Water Surfaces', 'WaveHeight',
#        'Weather Conditions Day Before Yesterday', 'Weather Conditions Today',
#        'Weather Conditions Yesterday', 'WindDirection', 'WindSpeed', 'state',
#        'Point', 'HUC12_', 'HUCNAME_', 'FIPS_', 'COUNTY_', 'STATE_'],
#       dtype='object')

# %%
#Take interested columns 
df2 = df.loc[:, ['Latitude', 
       'Longitude', 'Date', 'Time', 'HUCNAME_', 'FIPS_', 'Point', 'Parameter',
       'ParameterName_CBP', 'ParameterName_CMC', 'MeasureValue', 'Unit', 'SampleId']]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2708717 entries, 0 to 2708716
# Data columns (total 13 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Latitude           float64
#  1   Longitude          float64
#  2   Date               object
#  3   Time               object
#  4   HUCNAME_           object
#  5   FIPS_              int64
#  6   Point              object
#  7   Parameter          object
#  8   ParameterName_CBP  object
#  9   ParameterName_CMC  object
#  10  MeasureValue       float64
#  11  Unit               object
#  12  SampleId           float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 289.3+ MB

# %%
df2['Parameter'].unique()
# Out:
# array(['CHL.3', 'DO.6', 'NO3N.5', 'SA.9', 'DO.5', 'NO3N.6', 'WC.2',
#        'WT.8', 'PH.6', 'CO.8', 'AT.3', 'OP.1', 'WT.1', 'NH4N.1', 'WT.4',
#        'AT.11', 'AT.2', 'CHL.1', 'ECOLI.4', 'TP.3', 'NO3N.1', 'ECOLI.6',
#        'CO.9', 'WC.7', 'OP.3', 'ECOLI.1', 'TDS.1', 'WT.5', 'WC.5', 'WC.6',
#        'AT.1', 'AT.10', 'NO3N.2', 'TDS.3', 'AT.9', 'ENT.2', 'WT.10',
#        'TD.1', 'WC.9', 'SA.3', 'SA.6', 'PH.11', 'DO.3', 'NO3N.4', 'DO.4',
#        'SA.2', 'TSS.1', 'CO.1', 'PH.10', 'OP.2', 'WC.12', 'CO.4', 'WT.3',
#        'WC.1', 'CO.2', 'ALKY.6', 'SA.10', 'PH.8', 'OP.8', 'NO2NO3.1',
#        'DO.2', 'DO.7', 'WC.4', 'DO.15', 'TSS.3', 'OP.7', 'WC.8', 'CHL.2',
#        'WT.12', 'TN.2', 'CO.5', 'OP.4', 'AT.4', 'TDS.2', 'NO3N.3', 'WT.2',
#        'WT.6', 'PH.9', 'SA.8', 'CHL.4', 'WT.9', 'SA.1', 'PH.7', 'PH.1',
#        'DO.9', 'TKN.1', 'ENT.1', 'WT.7', 'DO.14', 'AT.5', 'OP.6', 'TP.2',
#        'PH.5', 'NO2NO3.4', 'TP.1', 'TN.1', 'PH.4', 'PH.2', 'ECOLI.2',
#        'DO.1', 'PH.3', 'AT.6', 'DO.8', 'TN.3', 'WT.13', 'ALKY.3', 'CHLA',
#        'DO', 'NH4F', 'NO3F', 'PH', 'PO4F', 'SALINITY', 'SECCHI', 'TN',
#        'TP', 'TSS', 'WTEMP', 'TURB_NTU', 'TALK', 'TDS', 'TKNW'],
#       dtype=object)

# %%
#lower case measurement unit as it some were uppercased for some odd reason 
df2['Unit'] = df2['Unit'].apply(lambda x: x.lower())

# %%
#combine the parameter and unit, the reason why I chose CBP is because it's more complete choosing parameter you only have chemical name 
#the problem with that and using only the first two letters is that they have different measurements in the rows 
df2['Parameter and Unit'] = df2['ParameterName_CBP'] + ' '+ df2['Unit']

# %%
#Pivot the table 
df_pivot = df2.pivot_table('MeasureValue', ['Date', 'SampleId', 'Longitude', 'Latitude', 'Time'], 'Parameter and Unit')

# %%
df_pivot = df_pivot.reset_index()

# %%
#df3.groupby(['Date', 'SampleId'])['MeasureValue'].aggregate('mean').unstack().reset_index()

# %%
#Not enough observations to keep and not sure what it is 
columns = ['Not in CBP Database cfu', 'Not in CBP Database mg/l',
       'Not in CBP Database mpn', 'Not in CBP Database ntu',
       'Not in CBP Database ppb', 'Not in CBP Database ppt',
       'Not in CBP Database su', 'Not in CBP Database ug/l']

df_pivot = df_pivot.drop(columns = columns)

# %%
df_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132449 entries, 0 to 132448
# Data columns (total 33 columns):
#  #   Column                                                                 Non-Null Count   Dtype
# ---  ------                                                                 --------------   -----
#  0   Date                                                                   132449 non-null  object
#  1   SampleId                                                               132449 non-null  float64
#  2   Longitude                                                              132449 non-null  float64
#  3   Latitude                                                               132449 non-null  float64
#  4   Time                                                                   132449 non-null  object
#  5   ACTIVE CHLOROPHYLL-A ug/l                                              58164 non-null   float64
#  6   AIR TEMPERATURE DEG deg c                                              16670 non-null   float64
#  7   AMMONIUM NITROGEN AS N (FILTERED SAMPLE) mg/l                          64686 non-null   float64
#  8   DISSOLVED OXYGEN IN MG/L mg/l                                          113018 non-null  float64
#  9   DO SATURATION USING PROBE UNITS IN PERCENT pct                         6308 non-null    float64
#  10  E.COLI BACTERIA mpn                                                    2612 non-null    float64
#  11  NITRATE NITROGEN AS N (FILTERED SAMPLE) mg/l                           59948 non-null   float64
#  12  ORTHOPHOSPHATE PHOSPHORUS AS P (FILTERED SAMPLE) mg/l                  74239 non-null   float64
#  13  ORTHOPHOSPHATE PHOSPHORUS AS P (FILTERED SAMPLE) ppm                   264 non-null     float64
#  14  PH CORRECTED FOR TEMPERATURE (25 DEG C) su                             108894 non-null  float64
#  15  SALINITY UNITS IN PPT AND EQUAL TO PRACTICAL SALNITY UNITS (PSU) mg/l  834 non-null     float64
#  16  SALINITY UNITS IN PPT AND EQUAL TO PRACTICAL SALNITY UNITS (PSU) pps   365 non-null     float64
#  17  SALINITY UNITS IN PPT AND EQUAL TO PRACTICAL SALNITY UNITS (PSU) ppt   68556 non-null   float64
#  18  SECCHI DEPTH m                                                         54730 non-null   float64
#  19  SPECIFIC CONDUCTIVITY ms/cm                                            28 non-null      float64
#  20  SPECIFIC CONDUCTIVITY us/cm                                            21542 non-null   float64
#  21  TOTAL ALKALINITY AS CACO3 mg/l                                         25146 non-null   float64
#  22  TOTAL DEPTH m                                                          4948 non-null    float64
#  23  TOTAL DISSOLVED SOLIDS; GRAVIMETRIC; DRIED AT 180 C mg/l               17603 non-null   float64
#  24  TOTAL KJELDAHL NITROGEN (WHOLE SAMPLE) mg/l                            13231 non-null   float64
#  25  TOTAL NITROGEN mg/l                                                    67133 non-null   float64
#  26  TOTAL PHOSPHORUS mg/l                                                  69284 non-null   float64
#  27  TOTAL SUSPENDED SOLIDS mg/l                                            80303 non-null   float64
#  28  TURBIDITY TUBE cm                                                      7618 non-null    float64
#  29  TURBIDITY; JACKSON CANDLE METHOD (FORWARD SCATTER) jtu                 3198 non-null    float64
#  30  TURBIDITY; NEPHELOMETRIC METHOD fau                                    73 non-null      float64
#  31  TURBIDITY; NEPHELOMETRIC METHOD ntu                                    30503 non-null   float64
#  32  WATER TEMPERATURE DEG deg c                                            118355 non-null  float64
# dtypes: float64(31), object(2)
# memory usage: 33.3+ MB

# %% [markdown]
# A Secchi disk is an 8-inch (20 cm) disk with alternating black and white quadrants. It is lowered into the water of a lake until it can no longer be seen by the observer. This depth of disappearance, called the Secchi depth, is a measure of the transparency of the water.
#
# Turbidity is a measurement of the amount of suspended material in the water. It describes the clarity of water. Suspended materials in water, such as clay, silt, and algae, reduce water clarity and cause turbidity.
#
# Parameter Importance
# Turbidity is an important indicator of the amount of suspended sediment in water, which can have many negative effects on aquatic life. The suspended sediments that cause turbidity can block light to aquatic plants, smother aquatic organisms, and carry contaminants and pathogens, such as lead, mercury, and bacteria.
#
# Long-term turbidity monitoring is very important because it helps us measure the amount of soil erosion due to construction and agriculture, and helps to determine the impact of our land-use practices and increasing urban development on water quality.
#
# How it is Measured
# Measuring turbidity is achieved by evaluating the amount of light scattered in water. This can be done with simple visual assessments, such as the original Jackson Candle turbidimeter, or more accurate, technological methods, such as the nephelometric method. Turbidity is reported in either NTUs or JTUs. These units refer to the method used to measure turbidity.
#
# The original method to measure turbidity was the Jackson candle Turbidimeter, which was devised around the turn of the century. The Jackson Candle Turbidimeter consists of flat-bottomed glass tube that sits over a candle. A water sample is poured into the tube until the visual image of the candle flame diffuses into a uniform glow. The depth of the sample corresponds to a certain number of Jackson turbidity units, or JTUs.
#
# The most accurate way to measure turbidity is with the nephelometric method. This method shines a concentrated beam of light through a water sample, and then measures the amount of scattered light at a 90 degree angle to the light source. The amount of scattered light is then reported in NTUs. The nephelometric method reflects a more precise measurement and is used by government agencies and in scientific research.
#
# Definition for Total Nitrogen
# The NPI NEPM states that total nitrogen refers only to those amounts of nitrogen
# that give rise to nitrate/nitrite ions. Since this may be possible for a range of
# nitrogen compounds in a range of environmental conditions, the following
# pragmatic definition can be applied:
# Total Nitrogen is the sum of nitrate (NO3), nitrite (NO2), organic nitrogen and
# ammonia (all expressed as N). Note that for laboratory analysis purposes, Total
# Kjeldahl Nitrogen (TKN) is a test performed that is made up of both organic
# nitrogen and ammonia.

# %%
#drop columns with a repeated measures that aren't as accurate as the ones kept 
df_pivot2 = df_pivot.drop(columns = ['DO SATURATION USING PROBE UNITS IN PERCENT pct', 'ORTHOPHOSPHATE PHOSPHORUS AS P (FILTERED SAMPLE) ppm',
                         'SALINITY UNITS IN PPT AND EQUAL TO PRACTICAL SALNITY UNITS (PSU) mg/l', 
                          'SALINITY UNITS IN PPT AND EQUAL TO PRACTICAL SALNITY UNITS (PSU) pps', 'SPECIFIC CONDUCTIVITY ms/cm',
                         'TURBIDITY; JACKSON CANDLE METHOD (FORWARD SCATTER) jtu', 'TURBIDITY; NEPHELOMETRIC METHOD fau'])

# %%
df_pivot2.describe().T
# Out:
#                                                        count           mean  \
# Parameter and Unit
# SampleId                                            132449.0  162353.172225
# Longitude                                           132449.0     -76.897939
# Latitude                                            132449.0      39.016295
# ACTIVE CHLOROPHYLL-A ug/l                            58164.0      13.605103
# AIR TEMPERATURE DEG deg c                            16670.0      17.425392
# AMMONIUM NITROGEN AS N (FILTERED SAMPLE) mg/l        64686.0       0.046587
# DISSOLVED OXYGEN IN MG/L mg/l                       113018.0       8.870668
# E.COLI BACTERIA mpn                                   2612.0     295.614460
# NITRATE NITROGEN AS N (FILTERED SAMPLE) mg/l         59948.0       1.080424
# ORTHOPHOSPHATE PHOSPHORUS AS P (FILTERED SAMPLE...   74239.0       0.029543
# PH CORRECTED FOR TEMPERATURE (25 DEG C) su          108894.0       7.546087
# SALINITY UNITS IN PPT AND EQUAL TO PRACTICAL SA...   68556.0       7.487385
# SECCHI DEPTH m                                       54730.0       0.883006
# SPECIFIC CONDUCTIVITY us/cm                          21542.0     248.763494
# TOTAL ALKALINITY AS CACO3 mg/l                       25146.0      80.083321
# TOTAL DEPTH m                                         4948.0       2.823042
# TOTAL DISSOLVED SOLIDS; GRAVIMETRIC; DRIED AT 1...   17603.0     225.616496
# TOTAL KJELDAHL NITROGEN (WHOLE SAMPLE) mg/l          13231.0       0.434853
# TOTAL NITROGEN mg/l                                  67133.0       1.554463
# TOTAL PHOSPHORUS mg/l                                69284.0       0.076344
# TOTAL SUSPENDED SOLIDS mg/l                          80303.0      26.932380
# TURBIDITY TUBE cm                                     7618.0      90.004701
# TURBIDITY; NEPHELOMETRIC METHOD ntu                  30503.0      19.872521
# WATER TEMPERATURE DEG deg c                         118355.0      16.192443
#
#                                                               std        min  \
# Parameter and Unit
# SampleId                                            189763.995712   1.000000
# Longitude                                                0.848614 -80.437078
# Latitude                                                 1.329020  36.740040
# ACTIVE CHLOROPHYLL-A ug/l                               21.608400   0.000000
# AIR TEMPERATURE DEG deg c                                8.903081 -14.000000
# AMMONIUM NITROGEN AS N (FILTERED SAMPLE) mg/l            0.073753  -0.232000
# DISSOLVED OXYGEN IN MG/L mg/l                            2.820095   0.000000
# E.COLI BACTERIA mpn                                    863.892346   0.000000
# NITRATE NITROGEN AS N (FILTERED SAMPLE) mg/l             1.983920  -0.012167
# ORTHOPHOSPHATE PHOSPHORUS AS P (FILTERED SAMPLE...       0.144505   0.000000
# PH CORRECTED FOR TEMPERATURE (25 DEG C) su               1.926461   0.000000
# SALINITY UNITS IN PPT AND EQUAL TO PRACTICAL SA...       7.835714   0.000000
# SECCHI DEPTH m                                           2.038396   0.000000
# SPECIFIC CONDUCTIVITY us/cm                            399.117999   0.030000
# TOTAL ALKALINITY AS CACO3 mg/l                          63.214232   0.000000
# TOTAL DEPTH m                                            3.514448   0.000000
# TOTAL DISSOLVED SOLIDS; GRAVIMETRIC; DRIED AT 1...     313.627184   4.200000
# TOTAL KJELDAHL NITROGEN (WHOLE SAMPLE) mg/l              0.417208  -1.200000
# TOTAL NITROGEN mg/l                                      4.181908   0.020000
# TOTAL PHOSPHORUS mg/l                                    0.119109  -0.006000
# TOTAL SUSPENDED SOLIDS mg/l                             92.601060   0.000000
# TURBIDITY TUBE cm                                       35.991242   0.000000
# TURBIDITY; NEPHELOMETRIC METHOD ntu                    177.435754   0.000000
# WATER TEMPERATURE DEG deg c                              8.317933  -6.000000
#
#                                                            25%           50%  \
# Parameter and Unit
# SampleId                                              1.000000  62677.000000
# Longitude                                           -77.339640    -76.713330
# Latitude                                             38.044300     38.909378
# ACTIVE CHLOROPHYLL-A ug/l                             3.738000      7.830000
# AIR TEMPERATURE DEG deg c                            10.700000     18.777778
# AMMONIUM NITROGEN AS N (FILTERED SAMPLE) mg/l         0.011000      0.025500
# DISSOLVED OXYGEN IN MG/L mg/l                         6.984000      8.800000
# E.COLI BACTERIA mpn                                  20.000000     70.000000
# NITRATE NITROGEN AS N (FILTERED SAMPLE) mg/l          0.024269      0.330950
# ORTHOPHOSPHATE PHOSPHORUS AS P (FILTERED SAMPLE...    0.004500      0.010175
# PH CORRECTED FOR TEMPERATURE (25 DEG C) su            7.222500      7.700000
# SALINITY UNITS IN PPT AND EQUAL TO PRACTICAL SA...    0.000000      5.587083
# SECCHI DEPTH m                                        0.400000      0.700000
# SPECIFIC CONDUCTIVITY us/cm                          47.000000    154.000000
# TOTAL ALKALINITY AS CACO3 mg/l                       38.000000     64.000000
# TOTAL DEPTH m                                         0.900000      1.800000
# TOTAL DISSOLVED SOLIDS; GRAVIMETRIC; DRIED AT 1...  110.000000    180.000000
# TOTAL KJELDAHL NITROGEN (WHOLE SAMPLE) mg/l           0.200000      0.310000
# TOTAL NITROGEN mg/l                                   0.627000      0.992500
# TOTAL PHOSPHORUS mg/l                                 0.028100      0.049000
# TOTAL SUSPENDED SOLIDS mg/l                           5.300000     11.000000
# TURBIDITY TUBE cm                                    59.000000    115.000000
# TURBIDITY; NEPHELOMETRIC METHOD ntu                   3.300000      7.305000
# WATER TEMPERATURE DEG deg c                           9.109063     16.520000
#
#                                                               75%  \
# Parameter and Unit
# SampleId                                            406157.000000
# Longitude                                              -76.294670
# Latitude                                                39.670480
# ACTIVE CHLOROPHYLL-A ug/l                               15.220000
# AIR TEMPERATURE DEG deg c                               24.500000
# AMMONIUM NITROGEN AS N (FILTERED SAMPLE) mg/l            0.054700
# DISSOLVED OXYGEN IN MG/L mg/l                           10.800000
# E.COLI BACTERIA mpn                                    260.000000
# NITRATE NITROGEN AS N (FILTERED SAMPLE) mg/l             1.228608
# ORTHOPHOSPHATE PHOSPHORUS AS P (FILTERED SAMPLE...       0.025500
# PH CORRECTED FOR TEMPERATURE (25 DEG C) su               8.000000
# SALINITY UNITS IN PPT AND EQUAL TO PRACTICAL SA...      13.810000
# SECCHI DEPTH m                                           1.100000
# SPECIFIC CONDUCTIVITY us/cm                            319.000000
# TOTAL ALKALINITY AS CACO3 mg/l                          98.000000
# TOTAL DEPTH m                                            3.500000
# TOTAL DISSOLVED SOLIDS; GRAVIMETRIC; DRIED AT 1...     292.000000
# TOTAL KJELDAHL NITROGEN (WHOLE SAMPLE) mg/l              0.530000
# TOTAL NITROGEN mg/l                                      1.751000
# TOTAL PHOSPHORUS mg/l                                    0.082969
# TOTAL SUSPENDED SOLIDS mg/l                             22.700000
# TURBIDITY TUBE cm                                      120.000000
# TURBIDITY; NEPHELOMETRIC METHOD ntu                     17.341667
# WATER TEMPERATURE DEG deg c                             23.500000
#
#                                                               max
# Parameter and Unit
# SampleId                                            462091.000000
# Longitude                                              -74.835244
# Latitude                                                42.806720
# ACTIVE CHLOROPHYLL-A ug/l                             1262.909975
# AIR TEMPERATURE DEG deg c                               83.000000
# AMMONIUM NITROGEN AS N (FILTERED SAMPLE) mg/l            2.553000
# DISSOLVED OXYGEN IN MG/L mg/l                          175.000000
# E.COLI BACTERIA mpn                                  27487.500000
# NITRATE NITROGEN AS N (FILTERED SAMPLE) mg/l            20.000000
# ORTHOPHOSPHATE PHOSPHORUS AS P (FILTERED SAMPLE...      22.000000
# PH CORRECTED FOR TEMPERATURE (25 DEG C) su             580.000000
# SALINITY UNITS IN PPT AND EQUAL TO PRACTICAL SA...      60.475000
# SECCHI DEPTH m                                         145.000000
# SPECIFIC CONDUCTIVITY us/cm                          15449.000000
# TOTAL ALKALINITY AS CACO3 mg/l                         945.000000
# TOTAL DEPTH m                                           43.000000
# TOTAL DISSOLVED SOLIDS; GRAVIMETRIC; DRIED AT 1...   24774.000000
# TOTAL KJELDAHL NITROGEN (WHOLE SAMPLE) mg/l              9.400000
# TOTAL NITROGEN mg/l                                    765.000000
# TOTAL PHOSPHORUS mg/l                                   10.000000
# TOTAL SUSPENDED SOLIDS mg/l                           9592.000000
# TURBIDITY TUBE cm                                      121.000000
# TURBIDITY; NEPHELOMETRIC METHOD ntu                  29777.000000
# WATER TEMPERATURE DEG deg c                            299.476667

# %%
df_pivot2
# Out:
# Parameter and Unit        Date  SampleId  Longitude  Latitude      Time  \
# 0                   01/01/1993       1.0  -77.18692  40.17999  12:00:00
# 1                   01/01/1993       1.0  -77.18606  40.18844  12:00:00
# 2                   01/01/1993       1.0  -77.18537  40.17663  12:00:00
# 3                   01/01/1993       1.0  -77.18507  40.17667  12:00:00
# 4                   01/01/1993       1.0  -77.18423  40.19528  12:00:00
# ...                        ...       ...        ...       ...       ...
# 132444                9/9/2019  459510.0  -76.12810  39.69030  08:30:00
# 132445                9/9/2019  459586.0  -76.36774  39.94649  11:00:00
# 132446                9/9/2019  461212.0  -77.93889  39.42361  13:10:00
# 132447                9/9/2019  461228.0  -77.83183  39.48308  09:10:00
# 132448                9/9/2019  461244.0  -77.78944  39.28194  11:20:00
#
# Parameter and Unit  ACTIVE CHLOROPHYLL-A ug/l  AIR TEMPERATURE DEG deg c  \
# 0                                         NaN                        NaN
# 1                                         NaN                        NaN
# 2                                         NaN                        NaN
# 3                                         NaN                        NaN
# 4                                         NaN                        NaN
# ...                                       ...                        ...
# 132444                                    NaN                        NaN
# 132445                                    NaN                        NaN
# 132446                                    NaN                        NaN
# 132447                                    NaN                        NaN
# 132448                                    NaN                        NaN
#
# Parameter and Unit  AMMONIUM NITROGEN AS N (FILTERED SAMPLE) mg/l  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ...                                                           ...
# 132444                                                      0.046
# 132445                                                      0.051
# 132446                                                      0.010
# 132447                                                      0.020
# 132448                                                      0.010
#
# Parameter and Unit  DISSOLVED OXYGEN IN MG/L mg/l  E.COLI BACTERIA mpn  ...  \
# 0                                           11.60                  NaN  ...
# 1                                           11.00                  NaN  ...
# 2                                           11.15                  NaN  ...
# 3                                           11.25                  NaN  ...
# 4                                           10.70                  NaN  ...
# ...                                           ...                  ...  ...
# 132444                                       8.83                  NaN  ...
# 132445                                       9.22                  NaN  ...
# 132446                                       9.90                  NaN  ...
# 132447                                       9.80                  NaN  ...
# 132448                                       8.20                  NaN  ...
#
# Parameter and Unit  TOTAL ALKALINITY AS CACO3 mg/l  TOTAL DEPTH m  \
# 0                                              NaN            NaN
# 1                                              NaN            NaN
# 2                                              NaN            NaN
# 3                                              NaN            NaN
# 4                                              NaN            NaN
# ...                                            ...            ...
# 132444                                        49.6            NaN
# 132445                                       193.0            NaN
# 132446                                         NaN            NaN
# 132447                                         NaN            NaN
# 132448                                         NaN            NaN
#
# Parameter and Unit  TOTAL DISSOLVED SOLIDS; GRAVIMETRIC; DRIED AT 180 C mg/l  \
# 0                                                               290.0
# 1                                                               385.0
# 2                                                               385.0
# 3                                                               330.0
# 4                                                               395.0
# ...                                                               ...
# 132444                                                          188.0
# 132445                                                          406.0
# 132446                                                            NaN
# 132447                                                            NaN
# 132448                                                            NaN
#
# Parameter and Unit  TOTAL KJELDAHL NITROGEN (WHOLE SAMPLE) mg/l  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
# ...                                                         ...
# 132444                                                    0.705
# 132445                                                      NaN
# 132446                                                      NaN
# 132447                                                      NaN
# 132448                                                      NaN
#
# Parameter and Unit  TOTAL NITROGEN mg/l  TOTAL PHOSPHORUS mg/l  \
# 0                                   NaN                    NaN
# 1                                   NaN                    NaN
# 2                                   NaN                    NaN
# 3                                   NaN                    NaN
# 4                                   NaN                    NaN
# ...                                 ...                    ...
# 132444                            7.198                  0.049
# 132445                              NaN                  0.158
# 132446                              NaN                  0.020
# 132447                              NaN                  0.010
# 132448                            1.273                  0.010
#
# Parameter and Unit  TOTAL SUSPENDED SOLIDS mg/l  TURBIDITY TUBE cm  \
# 0                                           NaN                NaN
# 1                                           NaN                NaN
# 2                                           NaN                NaN
# 3                                           NaN                NaN
# 4                                           NaN                NaN
# ...                                         ...                ...
# 132444                                      5.0                NaN
# 132445                                      6.0                NaN
# 132446                                     15.0                NaN
# 132447                                     15.0                NaN
# 132448                                     15.0                NaN
#
# Parameter and Unit  TURBIDITY; NEPHELOMETRIC METHOD ntu  \
# 0                                                  2.40
# 1                                                  4.15
# 2                                                  0.75
# 3                                                  2.00
# 4                                                  4.15
# ...                                                 ...
# 132444                                              NaN
# 132445                                              NaN
# 132446                                              NaN
# 132447                                              NaN
# 132448                                              NaN
#
# Parameter and Unit  WATER TEMPERATURE DEG deg c
# 0                                          9.25
# 1                                          8.50
# 2                                          9.50
# 3                                          8.85
# 4                                          8.50
# ...                                         ...
# 132444                                    20.86
# 132445                                    20.58
# 132446                                    20.90
# 132447                                    15.20
# 132448                                    24.30
#
# [132449 rows x 26 columns]

# %%
#combine time to merge with Bryans dataset 
df_pivot2['DateTime'] = df_pivot2['Date'] + ' ' + df_pivot2['Time']

# %%
#change to datetime 
import dateutil.parser
df_pivot2['DateTime'] = df_pivot2['DateTime'].apply(lambda x :  dateutil.parser.parse(x))

# %%
df_pivot2 = df_pivot2.drop(columns = ['Date', 'Time'])

# %%
df_pivot2
# Out:
# Parameter and Unit  SampleId  Longitude  Latitude  ACTIVE CHLOROPHYLL-A ug/l  \
# 0                        1.0  -77.18692  40.17999                        NaN
# 1                        1.0  -77.18606  40.18844                        NaN
# 2                        1.0  -77.18537  40.17663                        NaN
# 3                        1.0  -77.18507  40.17667                        NaN
# 4                        1.0  -77.18423  40.19528                        NaN
# ...                      ...        ...       ...                        ...
# 132444              459510.0  -76.12810  39.69030                        NaN
# 132445              459586.0  -76.36774  39.94649                        NaN
# 132446              461212.0  -77.93889  39.42361                        NaN
# 132447              461228.0  -77.83183  39.48308                        NaN
# 132448              461244.0  -77.78944  39.28194                        NaN
#
# Parameter and Unit  AIR TEMPERATURE DEG deg c  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 132444                                    NaN
# 132445                                    NaN
# 132446                                    NaN
# 132447                                    NaN
# 132448                                    NaN
#
# Parameter and Unit  AMMONIUM NITROGEN AS N (FILTERED SAMPLE) mg/l  \
# 0                                                             NaN
# 1                                                             NaN
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# ...                                                           ...
# 132444                                                      0.046
# 132445                                                      0.051
# 132446                                                      0.010
# 132447                                                      0.020
# 132448                                                      0.010
#
# Parameter and Unit  DISSOLVED OXYGEN IN MG/L mg/l  E.COLI BACTERIA mpn  \
# 0                                           11.60                  NaN
# 1                                           11.00                  NaN
# 2                                           11.15                  NaN
# 3                                           11.25                  NaN
# 4                                           10.70                  NaN
# ...                                           ...                  ...
# 132444                                       8.83                  NaN
# 132445                                       9.22                  NaN
# 132446                                       9.90                  NaN
# 132447                                       9.80                  NaN
# 132448                                       8.20                  NaN
#
# Parameter and Unit  NITRATE NITROGEN AS N (FILTERED SAMPLE) mg/l  \
# 0                                                          6.200
# 1                                                          6.200
# 2                                                          5.300
# 3                                                          5.900
# 4                                                          6.050
# ...                                                          ...
# 132444                                                       NaN
# 132445                                                       NaN
# 132446                                                     1.695
# 132447                                                     2.460
# 132448                                                     0.962
#
# Parameter and Unit  ORTHOPHOSPHATE PHOSPHORUS AS P (FILTERED SAMPLE) mg/l  \
# 0                                                               0.150
# 1                                                               0.100
# 2                                                               0.100
# 3                                                               0.100
# 4                                                               0.150
# ...                                                               ...
# 132444                                                          0.025
# 132445                                                          0.123
# 132446                                                          0.011
# 132447                                                          0.004
# 132448                                                          0.004
#
# Parameter and Unit  ...  TOTAL DEPTH m  \
# 0                   ...            NaN
# 1                   ...            NaN
# 2                   ...            NaN
# 3                   ...            NaN
# 4                   ...            NaN
# ...                 ...            ...
# 132444              ...            NaN
# 132445              ...            NaN
# 132446              ...            NaN
# 132447              ...            NaN
# 132448              ...            NaN
#
# Parameter and Unit  TOTAL DISSOLVED SOLIDS; GRAVIMETRIC; DRIED AT 180 C mg/l  \
# 0                                                               290.0
# 1                                                               385.0
# 2                                                               385.0
# 3                                                               330.0
# 4                                                               395.0
# ...                                                               ...
# 132444                                                          188.0
# 132445                                                          406.0
# 132446                                                            NaN
# 132447                                                            NaN
# 132448                                                            NaN
#
# Parameter and Unit  TOTAL KJELDAHL NITROGEN (WHOLE SAMPLE) mg/l  \
# 0                                                           NaN
# 1                                                           NaN
# 2                                                           NaN
# 3                                                           NaN
# 4                                                           NaN
# ...                                                         ...
# 132444                                                    0.705
# 132445                                                      NaN
# 132446                                                      NaN
# 132447                                                      NaN
# 132448                                                      NaN
#
# Parameter and Unit  TOTAL NITROGEN mg/l  TOTAL PHOSPHORUS mg/l  \
# 0                                   NaN                    NaN
# 1                                   NaN                    NaN
# 2                                   NaN                    NaN
# 3                                   NaN                    NaN
# 4                                   NaN                    NaN
# ...                                 ...                    ...
# 132444                            7.198                  0.049
# 132445                              NaN                  0.158
# 132446                              NaN                  0.020
# 132447                              NaN                  0.010
# 132448                            1.273                  0.010
#
# Parameter and Unit  TOTAL SUSPENDED SOLIDS mg/l  TURBIDITY TUBE cm  \
# 0                                           NaN                NaN
# 1                                           NaN                NaN
# 2                                           NaN                NaN
# 3                                           NaN                NaN
# 4                                           NaN                NaN
# ...                                         ...                ...
# 132444                                      5.0                NaN
# 132445                                      6.0                NaN
# 132446                                     15.0                NaN
# 132447                                     15.0                NaN
# 132448                                     15.0                NaN
#
# Parameter and Unit  TURBIDITY; NEPHELOMETRIC METHOD ntu  \
# 0                                                  2.40
# 1                                                  4.15
# 2                                                  0.75
# 3                                                  2.00
# 4                                                  4.15
# ...                                                 ...
# 132444                                              NaN
# 132445                                              NaN
# 132446                                              NaN
# 132447                                              NaN
# 132448                                              NaN
#
# Parameter and Unit  WATER TEMPERATURE DEG deg c            DateTime
# 0                                          9.25 1993-01-01 12:00:00
# 1                                          8.50 1993-01-01 12:00:00
# 2                                          9.50 1993-01-01 12:00:00
# 3                                          8.85 1993-01-01 12:00:00
# 4                                          8.50 1993-01-01 12:00:00
# ...                                         ...                 ...
# 132444                                    20.86 2019-09-09 08:30:00
# 132445                                    20.58 2019-09-09 11:00:00
# 132446                                    20.90 2019-09-09 13:10:00
# 132447                                    15.20 2019-09-09 09:10:00
# 132448                                    24.30 2019-09-09 11:20:00
#
# [132449 rows x 25 columns]

# %%
df_pivot3 = df_pivot2[df_pivot2['DateTime'] > '2009-12-31']

# %%
df_pivot3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96603 entries, 45 to 132448
# Data columns (total 25 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   SampleId                                                              96603 non-null  float64
#  1   Longitude                                                             96603 non-null  float64
#  2   Latitude                                                              96603 non-null  float64
#  3   ACTIVE CHLOROPHYLL-A ug/l                                             35770 non-null  float64
#  4   AIR TEMPERATURE DEG deg c                                             15657 non-null  float64
#  5   AMMONIUM NITROGEN AS N (FILTERED SAMPLE) mg/l                         41525 non-null  float64
#  6   DISSOLVED OXYGEN IN MG/L mg/l                                         79684 non-null  float64
#  7   E.COLI BACTERIA mpn                                                   2612 non-null   float64
#  8   NITRATE NITROGEN AS N (FILTERED SAMPLE) mg/l                          35590 non-null  float64
#  9   ORTHOPHOSPHATE PHOSPHORUS AS P (FILTERED SAMPLE) mg/l                 47866 non-null  float64
#  10  PH CORRECTED FOR TEMPERATURE (25 DEG C) su                            75172 non-null  float64
#  11  SALINITY UNITS IN PPT AND EQUAL TO PRACTICAL SALNITY UNITS (PSU) ppt  45118 non-null  float64
#  12  SECCHI DEPTH m                                                        34076 non-null  float64
#  13  SPECIFIC CONDUCTIVITY us/cm                                           20718 non-null  float64
#  14  TOTAL ALKALINITY AS CACO3 mg/l                                        17504 non-null  float64
#  15  TOTAL DEPTH m                                                         4948 non-null   float64
#  16  TOTAL DISSOLVED SOLIDS; GRAVIMETRIC; DRIED AT 180 C mg/l              14793 non-null  float64
#  17  TOTAL KJELDAHL NITROGEN (WHOLE SAMPLE) mg/l                           11813 non-null  float64
#  18  TOTAL NITROGEN mg/l                                                   44230 non-null  float64
#  19  TOTAL PHOSPHORUS mg/l                                                 45762 non-null  float64
#  20  TOTAL SUSPENDED SOLIDS mg/l                                           53307 non-null  float64
#  21  TURBIDITY TUBE cm                                                     7588 non-null   float64
#  22  TURBIDITY; NEPHELOMETRIC METHOD ntu                                   19975 non-null  float64
#  23  WATER TEMPERATURE DEG deg c                                           84337 non-null  float64
#  24  DateTime                                                              96603 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(24)
# memory usage: 19.2 MB

# %%
df_pivot3 = df_pivot3.rename_axis(None, axis=1)

# %%
df_pivot3.corr()['TOTAL NITROGEN mg/l']
# Out:
# SampleId                                                               -0.043412
# Longitude                                                               0.056085
# Latitude                                                                0.178259
# ACTIVE CHLOROPHYLL-A ug/l                                               0.136843
# AIR TEMPERATURE DEG deg c                                              -0.005245
# AMMONIUM NITROGEN AS N (FILTERED SAMPLE) mg/l                           0.069650
# DISSOLVED OXYGEN IN MG/L mg/l                                           0.046745
# E.COLI BACTERIA mpn                                                     0.077122
# NITRATE NITROGEN AS N (FILTERED SAMPLE) mg/l                            0.917744
# ORTHOPHOSPHATE PHOSPHORUS AS P (FILTERED SAMPLE) mg/l                   0.382497
# PH CORRECTED FOR TEMPERATURE (25 DEG C) su                             -0.009185
# SALINITY UNITS IN PPT AND EQUAL TO PRACTICAL SALNITY UNITS (PSU) ppt   -0.556799
# SECCHI DEPTH m                                                         -0.079703
# SPECIFIC CONDUCTIVITY us/cm                                            -0.049421
# TOTAL ALKALINITY AS CACO3 mg/l                                          0.484360
# TOTAL DEPTH m                                                          -0.264257
# TOTAL DISSOLVED SOLIDS; GRAVIMETRIC; DRIED AT 180 C mg/l                0.042573
# TOTAL KJELDAHL NITROGEN (WHOLE SAMPLE) mg/l                             0.225344
# TOTAL NITROGEN mg/l                                                     1.000000
# TOTAL PHOSPHORUS mg/l                                                   0.312583
# TOTAL SUSPENDED SOLIDS mg/l                                             0.118442
# TURBIDITY TUBE cm                                                       0.114817
# TURBIDITY; NEPHELOMETRIC METHOD ntu                                     0.107822
# WATER TEMPERATURE DEG deg c                                            -0.048472
# Name: TOTAL NITROGEN mg/l, dtype: float64

# %%
df_pivot4 = df_pivot3.drop(columns = 'SampleId')
df_pivot4 = df_pivot4.set_index('DateTime')

# %%
#df_pivot3.to_csv('chemical.csv')

# %%
#preprocessing 
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer
from sklearn.feature_selection import VarianceThreshold

#metrics
from sklearn.metrics import r2_score
from sklearn.metrics import explained_variance_score
from sklearn.metrics import mean_squared_error

#algorithms 
import xgboost as xgb

#hyptertuning
from sklearn.model_selection import RandomizedSearchCV

#Scalers 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PowerTransformer

# %%
df_pivot4['TOTAL NITROGEN mg/l'] = df_pivot4['TOTAL NITROGEN mg/l'].replace(np.nan, 'nan')
df_nitro = df_pivot4[df_pivot4['TOTAL NITROGEN mg/l'] != 'nan']

# %%
df_nitro.info()
#drop all columns
#air temperature 
#specific conductivity
#tubidity tube
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 44230 entries, 2017-01-16 14:15:00 to 2019-09-09 11:20:00
# Data columns (total 23 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   Longitude                                                             44230 non-null  float64
#  1   Latitude                                                              44230 non-null  float64
#  2   ACTIVE CHLOROPHYLL-A ug/l                                             24623 non-null  float64
#  3   AIR TEMPERATURE DEG deg c                                             471 non-null    float64
#  4   AMMONIUM NITROGEN AS N (FILTERED SAMPLE) mg/l                         36237 non-null  float64
#  5   DISSOLVED OXYGEN IN MG/L mg/l                                         43129 non-null  float64
#  6   E.COLI BACTERIA mpn                                                   1355 non-null   float64
#  7   NITRATE NITROGEN AS N (FILTERED SAMPLE) mg/l                          29302 non-null  float64
#  8   ORTHOPHOSPHATE PHOSPHORUS AS P (FILTERED SAMPLE) mg/l                 41091 non-null  float64
#  9   PH CORRECTED FOR TEMPERATURE (25 DEG C) su                            40874 non-null  float64
#  10  SALINITY UNITS IN PPT AND EQUAL TO PRACTICAL SALNITY UNITS (PSU) ppt  27623 non-null  float64
#  11  SECCHI DEPTH m                                                        19423 non-null  float64
#  12  SPECIFIC CONDUCTIVITY us/cm                                           862 non-null    float64
#  13  TOTAL ALKALINITY AS CACO3 mg/l                                        11878 non-null  float64
#  14  TOTAL DEPTH m                                                         2109 non-null   float64
#  15  TOTAL DISSOLVED SOLIDS; GRAVIMETRIC; DRIED AT 180 C mg/l              6626 non-null   float64
#  16  TOTAL KJELDAHL NITROGEN (WHOLE SAMPLE) mg/l                           11614 non-null  float64
#  17  TOTAL NITROGEN mg/l                                                   44230 non-null  object
#  18  TOTAL PHOSPHORUS mg/l                                                 42661 non-null  float64
#  19  TOTAL SUSPENDED SOLIDS mg/l                                           40797 non-null  float64
#  20  TURBIDITY TUBE cm                                                     119 non-null    float64
#  21  TURBIDITY; NEPHELOMETRIC METHOD ntu                                   13929 non-null  float64
#  22  WATER TEMPERATURE DEG deg c                                           43765 non-null  float64
# dtypes: float64(22), object(1)
# memory usage: 8.1+ MB

# %%
df_nitro = df_nitro.drop(columns = ['AIR TEMPERATURE DEG deg c','SPECIFIC CONDUCTIVITY us/cm', 'TURBIDITY TUBE cm'])

# %%
#Outliers
df_nitro = df_nitro[df_nitro['TOTAL NITROGEN mg/l'] < 50]

# %%
df_nitro.to_csv('dfnitro.csv')

# %%
#Train Test Split
X_train, X_test, y_train, y_test = train_test_split(df_nitro.drop(labels = 'TOTAL NITROGEN mg/l', axis = 1), 
                                                    df_nitro['TOTAL NITROGEN mg/l'], test_size = 0.3, random_state = 0)
X_train.shape, X_test.shape
# Out:
# ((30940, 19), (13260, 19))

# %%
xgb = xgb.XGBRegressor(random_state=0, n_jobs = -1)

# %%
xgb.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster=None, colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints=None,
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=-1, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method=None, validate_parameters=False, verbosity=None)

# %%
y_pred = xgb.predict(X_test)

# %%
#Standard Scaler
print(r2_score(y_test, y_pred))
print(explained_variance_score(y_test, y_pred))
print(np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# 0.8711003126026277
# 0.8711179515393547
# 0.6759750132010013

# %%
features = X_train.columns
#get feature importance attributed by random forest model
importance = pd.concat([pd.Series(features),
                       pd.Series(xgb.feature_importances_)], axis = 1)

importance.columns = ['feature', 'importance']
importance.sort_values(by = 'importance', ascending = False)
# Out:
#                                               feature  importance
# 6        NITRATE NITROGEN AS N (FILTERED SAMPLE) mg/l    0.316955
# 1                                            Latitude    0.166834
# 15                              TOTAL PHOSPHORUS mg/l    0.137878
# 11                     TOTAL ALKALINITY AS CACO3 mg/l    0.078170
# 0                                           Longitude    0.056119
# 7   ORTHOPHOSPHATE PHOSPHORUS AS P (FILTERED SAMPL...    0.042419
# 18                        WATER TEMPERATURE DEG deg c    0.029504
# 9   SALINITY UNITS IN PPT AND EQUAL TO PRACTICAL S...    0.028356
# 14        TOTAL KJELDAHL NITROGEN (WHOLE SAMPLE) mg/l    0.023000
# 17                TURBIDITY; NEPHELOMETRIC METHOD ntu    0.019999
# 8          PH CORRECTED FOR TEMPERATURE (25 DEG C) su    0.017870
# 16                        TOTAL SUSPENDED SOLIDS mg/l    0.017618
# 3       AMMONIUM NITROGEN AS N (FILTERED SAMPLE) mg/l    0.015593
# 10                                     SECCHI DEPTH m    0.012136
# 2                           ACTIVE CHLOROPHYLL-A ug/l    0.011363
# 4                       DISSOLVED OXYGEN IN MG/L mg/l    0.009431
# 12                                      TOTAL DEPTH m    0.007155
# 13  TOTAL DISSOLVED SOLIDS; GRAVIMETRIC; DRIED AT ...    0.007110
# 5                                 E.COLI BACTERIA mpn    0.002492

# %%
X_train2 = X_train.drop(columns = ['DISSOLVED OXYGEN IN MG/L mg/l', 'E.COLI BACTERIA mpn', 'TOTAL DEPTH m',
       'TOTAL DISSOLVED SOLIDS; GRAVIMETRIC; DRIED AT 180 C mg/l'])

X_test2 = X_test.drop(columns = ['DISSOLVED OXYGEN IN MG/L mg/l', 'E.COLI BACTERIA mpn', 'TOTAL DEPTH m',
       'TOTAL DISSOLVED SOLIDS; GRAVIMETRIC; DRIED AT 180 C mg/l'])

# %%
xgb.fit(X_train2, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster=None, colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints=None,
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=-1, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method=None, validate_parameters=False, verbosity=None)

# %%
y_pred2 = xgb.predict(X_test2)

# %%
#Standard Scaler
print(r2_score(y_test, y_pred2))
print(explained_variance_score(y_test, y_pred2))
print(np.sqrt(mean_squared_error(y_test, y_pred2)))
# Out:
# 0.8645247750150883
# 0.8645480792416336
# 0.693002260665122

# %%
features = X_train2.columns
#get feature importance attributed by random forest model
importance = pd.concat([pd.Series(features),
                       pd.Series(xgb.feature_importances_)], axis = 1)

importance.columns = ['feature', 'importance']
importance.sort_values(by = 'importance', ascending = False)
# Out:
#                                               feature  importance
# 4        NITRATE NITROGEN AS N (FILTERED SAMPLE) mg/l    0.288252
# 1                                            Latitude    0.186589
# 11                              TOTAL PHOSPHORUS mg/l    0.140260
# 9                      TOTAL ALKALINITY AS CACO3 mg/l    0.089225
# 0                                           Longitude    0.070221
# 5   ORTHOPHOSPHATE PHOSPHORUS AS P (FILTERED SAMPL...    0.046327
# 7   SALINITY UNITS IN PPT AND EQUAL TO PRACTICAL S...    0.034332
# 14                        WATER TEMPERATURE DEG deg c    0.025634
# 10        TOTAL KJELDAHL NITROGEN (WHOLE SAMPLE) mg/l    0.024927
# 12                        TOTAL SUSPENDED SOLIDS mg/l    0.021231
# 6          PH CORRECTED FOR TEMPERATURE (25 DEG C) su    0.017287
# 13                TURBIDITY; NEPHELOMETRIC METHOD ntu    0.015219
# 3       AMMONIUM NITROGEN AS N (FILTERED SAMPLE) mg/l    0.014677
# 8                                      SECCHI DEPTH m    0.013620
# 2                           ACTIVE CHLOROPHYLL-A ug/l    0.012198

# %%
#save models and predictions 
predictions_df = pd.DataFrame()
predictions_df['Actual'] = y_test
predictions_df['pred1'] = y_pred
predictions_df['pred2'] = y_pred2

# %%
predictions_df.to_csv('predictions_df.csv')

# %%
import joblib
# save the model to disk
xgb = 'xgb.sav'
joblib.dump(xgb, xgb)
# Out:
# ['xgb.sav']
